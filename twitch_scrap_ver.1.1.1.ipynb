# %%
import json
import urllib.request
from datetime import datetime
from datetime import timedelta
import re

import pandas as pd

# %%
twitch_game=pd.DataFrame(columns=['name','pop','_id','giantbomb_id','localized_name','locale','viewers','channels'])

# %% [markdown]
# ## twitch v5 api

# %% [markdown]
# ### Top games
#
# viewers : 해당 게임을 시청하는 시청자 수
# channels : 방송중인(방송한) 채널 수
# name : 게임 이름
# popularity : 인기도
# ID : twitch 서비스 내 고유키
# giantbomb_id : Giantbomb.com 미국의 비디오 게임 웹사이트. 위키(공략), 논평, 뉴스 등을 제공
# localized_name : locale에 맞춘 명칭
# locale : 기준 지역 기본 수집은 'en-us'

# %%
#game popularity rate. 요청 시점에서 시청자 수 기준으로 정렬

Clientid = "" #api client id 입력
lim = 100 #최대 요청 100, 응답 99개

url = "https://api.twitch.tv/kraken/games/top?"+"&limit="+str(lim)
req = urllib.request.Request(url, headers = {"Client-ID": Clientid, "Accept":"application/vnd.twitchtv.v5+jason"})
u = urllib.request.urlopen(req)
c = u.read().decode('utf-8')
js = json.loads(c)
results = js['top']

# %%
#results[0]['game']
for i in range(len(results)):
    print(results[i]['game']['name'])
# Out:
# League of Legends
# Just Chatting
# Escape From Tarkov
# World of Warcraft
# Grand Theft Auto V
# Fortnite
# Overwatch
# Apex Legends
# Hearthstone
# Dota 2
# Call of Duty: Modern Warfare
# Counter-Strike: Global Offensive
# Dead by Daylight
# Warcraft III
# Tom Clancy's Rainbow Six: Siege
# PLAYERUNKNOWN'S BATTLEGROUNDS
# Minecraft
# Super Smash Bros. Ultimate
# NBA 2K20
# Legends of Runeterra
# Dungeons & Dragons
# Magic: The Gathering
# ASMR
# Temtem
# Path of Exile
# Music & Performing Arts
# FIFA 20
# Slots
# Old School RuneScape
# Monster Hunter World
# Teamfight Tactics
# Art
# Destiny 2
# Dark Souls III
# Call of Duty: Black Ops 4
# Pokémon Sword/Shield
# Mario Kart 8
# Outer Wilds
# Retro
# Plague Inc: Evolved
# Rocket League
# StarCraft II
# Smite
# Street Fighter V
# Muppet Treasure Island
# Mobile Legends: Bang bang
# Black Desert Online
# Poker
# Super Mario Maker 2
# Sea of Thieves
# Madden NFL 20
# Doom
# FINAL FANTASY XIV Online
# Conan Exiles
# Dragon Ball Z: Kakarot
# God of War
# Rust
# Marbles On Stream
# Sports & Fitness
# Heroes of the Storm
# Jump King
# Tibia
# Slay the Spire
# Journey to the Savage Planet
# Kingdom Hearts III
# Talk Shows & Podcasts
# Super Metroid
# The Evil Within 2
# The Sims 4
# The Legend of Zelda: Ocarina of Time
# Makers & Crafting
# Yu-Gi-Oh! Duel Links
# VRChat
# PUBG MOBILE
# Grand Theft Auto: Vice City
# Red Dead Redemption 2
# Diablo II: Lord of Destruction
# The Elder Scrolls Online
# Total War: Three Kingdoms
# Destiny
# Monster Hunter World: Iceborne
# World of Tanks
# Life Is Strange 2
# Resident Evil 2
# Stardew Valley
# World of Warships
# ARK
# La-Mulana
# Super Smash Bros. Melee
# Dark Souls
# Science & Technology
# The Witcher 3: Wild Hunt
# MapleStory
# Tekken 7
# Fallout: New Vegas
# DayZ
# The Walking Dead: Saints & Sinners
# Bloodborne
# Code Vein

# %%
for i in range(len(results)):
    name = results[i]['game']['name']
    pop = results[i]['game']['popularity']
    iD = results[i]['game']['_id']
    bomb = results[i]['game']['giantbomb_id']
    local_name = results[i]['game']['localized_name']
    local = results[i]['game']['locale']
    view = results[i]['viewers']
    channel = results[i]['channels']
    twitch_game = twitch_game.append({'name':name,'pop':pop,'_id':iD,'giantbomb_id':bomb,'localized_name':local_name,'locale':local,'viewers':view,'channels':channel},ignore_index = True)

# %%
#twitch_game[(twitch_game['name']=='Overwatch')]
twitch_game
# Out:
#                                     name     pop     _id giantbomb_id  \
# 0                      League of Legends  120658   21779        24024
# 1                          Just Chatting   99849  509658            0
# 2                     Escape From Tarkov   88541  491931        53106
# 3                      World of Warcraft   61722   18122        19783
# 4                     Grand Theft Auto V   52181   32982        36765
# 5                               Fortnite   35693   33214        37030
# 6                              Overwatch   34550  488552        48190
# 7                           Apex Legends   23756  511224        72014
# 8                            Hearthstone   23245  138585        42033
# 9                                 Dota 2   19449   29595        32887
# 10          Call of Duty: Modern Warfare   19304  512710        73517
# 11      Counter-Strike: Global Offensive   14392   32399        36113
# 12                      Dead by Daylight   12336  491487        52693
# 13                          Warcraft III   12500   12924        14073
# 14       Tom Clancy's Rainbow Six: Siege   15493  460630        46562
# 15         PLAYERUNKNOWN'S BATTLEGROUNDS   11774  493057        54979
# 16                             Minecraft   12054   27471        30475
# 17            Super Smash Bros. Ultimate    9136  504461        66900
# 18                              NBA 2K20    8039  513319        74150
# 19                  Legends of Runeterra    8412  514790        75708
# 20                    Dungeons & Dragons    8068  509577            0
# 21                  Magic: The Gathering    7068    2748        68425
# 22                                  ASMR    6872  509659            0
# 23                                Temtem    6657  510336        71032
# 24                         Path of Exile    7578   29307        32562
# 25               Music & Performing Arts    6550   26936        29887
# 26                               FIFA 20    6280  512804        73601
# 27                                 Slots    6467  498566        54193
# 28                  Old School RuneScape    6163  459931        45837
# 29                  Monster Hunter World    5672  497467        59924
# ..                                   ...     ...     ...          ...
# 69  The Legend of Zelda: Ocarina of Time    1499   11557        12572
# 70                     Makers & Crafting    1506  509673            0
# 71                  Yu-Gi-Oh! Duel Links    1458  494508        58049
# 72                                VRChat    1524  499003        61444
# 73                           PUBG MOBILE    1409  505884        67843
# 74           Grand Theft Auto: Vice City    1458   15631        17036
# 75                 Red Dead Redemption 2    1266  493959        56725
# 76        Diablo II: Lord of Destruction    1313   14304        15589
# 77              The Elder Scrolls Online    1507   65654        38206
# 78             Total War: Three Kingdoms    1307  502377        64883
# 79                               Destiny    1200  280721        36067
# 80        Monster Hunter World: Iceborne    1581  515755        76618
# 81                        World of Tanks    1368   27546        30567
# 82                     Life Is Strange 2    1271  497103        59609
# 83                       Resident Evil 2    1129  490868        50601
# 84                        Stardew Valley    1112  490744        50899
# 87                             La-Mulana  en-us    1086        5
# 88               Super Smash Bros. Melee  en-us    1068       25
# 89                            Dark Souls  en-us    1068       50
# 90                  Science & Technology  en-us    1010      111
# 91              The Witcher 3: Wild Hunt  en-us    1002      153
# 92                            MapleStory  en-us    1002       68
# 93                              Tekken 7  en-us     999       64
# 94                    Fallout: New Vegas  en-us     960       18
# 95                                  DayZ  en-us     951      114
# 96    The Walking Dead: Saints & Sinners  en-us     921       23
# 97                            Bloodborne  en-us     895       52
# 98                             Code Vein  en-us     879       51
#
# [99 rows x 8 columns]

# %% [markdown]
# ### Streamer
#
# #### 비트 후원이 가능한 스트리머: 파트너, 제휴 스트리머
#     broadcaster_type: "partner", "affiliate", or ""
# 영어권 스트리머 data scrap
# 대상 언어권 스트리머 중 일정 규모의 시청자, 구독 조건의 스트리머 선택
# 선택된 스트리머 리스트의 동영상 URL 리스트 수집
# 수집된 URL, 작성한 api function으로 수집할 수 있도록 작성(일일 제한양에 맞춰 나누기)
#
# 조회한 대상이 파트너인지, 제휴인지, 그외 인지 pandas로 기록(중복 조회 피하기)
# id와 login을 함께 기록

# %%
twitch_channel=pd.DataFrame(columns=['id','login','partner','affiliate','ect','view_count'])

# %%
twitch_channel
# Out:
# Empty DataFrame
# Columns: [id, login, partner, affiliate, ect, view_count]
# Index: []

# %%
Clientid = "" #api client id 입력

# %%
#broadcaster_type
userID = "43691"

url = "https://api.twitch.tv/helix/users"+"?id="+userID
req = urllib.request.Request(url, headers = {"Client-ID": Clientid, "Authorization" : "Bearer cfabdegwdoklmawdzdo98xt2fo512y"})
u = urllib.request.urlopen(req)
c = u.read().decode('utf-8')
js = json.loads(c)

# %%
js
# Out:
# {'data': [{'id': '43691',
#    'login': 'faker',
#    'display_name': 'Faker',
#    'type': '',
#    'broadcaster_type': 'partner',
#    'description': '',
#    'profile_image_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/b2eb8a23-d6ad-45aa-bd8e-062133b64452-profile_image-300x300.png',
#    'offline_image_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/7d76e34d-3ee3-42c0-a46b-e320d37fcde6-channel_offline_image-1920x1080.jpeg',
#    'view_count': 73188956}]}

# %%
chan_ID = js['data'][0]['id']

# %%
login_ID = js['data'][0]['login']

# %%
partner = 0
affiliate = 0
ect = 0

Btype = js['data'][0]['broadcaster_type']
if Btype == 'partner':
    partner = 1
elif Btype == 'affiliate':
    affiliate = 1
else:
    ect = 1

# %%
view_count = js1['data'][0]['view_count']

# %%
twitch_channel=twitch_channel.append({'id':chan_ID,'login':login_ID,'partner':partner,'affiliate':affiliate,'ect':ect,'view_count':view_count},ignore_index = True)

# %%
twitch_channel
# Out:
#       id  login partner affiliate ect view_count
# 0  43691  faker       1         0   0   73188940

# %%
#broadcaster_type
userID2 = " " #조회 대상 ID

url2 = "https://api.twitch.tv/helix/users"+"?login="+userID2
req2 = urllib.request.Request(url2, headers = {"Client-ID": Clientid, "Authorization" : "Bearer cfabdegwdoklmawdzdo98xt2fo512y"})
u2 = urllib.request.urlopen(req2)
c2 = u2.read().decode('utf-8')
js2 = json.loads(c2)

# %%
js2
# Out:
# {'data': [{'id': '43691',
#    'login': 'faker',
#    'display_name': 'Faker',
#    'type': '',
#    'broadcaster_type': 'partner',
#    'description': '',
#    'profile_image_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/b2eb8a23-d6ad-45aa-bd8e-062133b64452-profile_image-300x300.png',
#    'offline_image_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/7d76e34d-3ee3-42c0-a46b-e320d37fcde6-channel_offline_image-1920x1080.jpeg',
#    'view_count': 73188956}]}

# %% [markdown]
# ### 스트리머의 게시된 영상 url 수집
#
# 대상 스트리머가 게시한 영상의 video ID를 수집하여 저장

# %%
channel_ID = " " #조회 대상 ID

url = "https://api.twitch.tv/kraken/channels/"+channel_ID+"/videos"
req = urllib.request.Request(url, headers = {"Client-ID": Clientid, "Accept":"application/vnd.twitchtv.v5+jason"})
u = urllib.request.urlopen(req)
c = u.read().decode('utf-8')
js = json.loads(c)

# %%
for i in range(len(js['videos'])):
    url = js['videos'][i]['url'].split('/')[-1]
    print(url)
# Out:
# 543118554
# 542642356
# 540013659
# 537368493
# 536379832
# 535882300
# 535396897
# 533301327

# %% [markdown]
# ### video

# %% [markdown]
# 영상 1건에 대한 채팅 수집
#
# 1. 수집 영상 video ID list 작성
# 2. 1에서 수집된 list로 각 영상의 전체 채팅 데이터 수집
# +데이터외에 영상에 대한 요약 정보(시간 외 api에서 요청가능한 정보 저장

# %%
scrapTW=pd.DataFrame(columns=['title','game_category','view','duration','vod_url','donation','spent','chat_time','time_stamp','comment_user','comments'])
scrapTW
# Out:
# Empty DataFrame
# Columns: [title, game_category, view, duration, vod_url, donation, spent, chat_time, time_stamp, comment_user, comments]
# Index: []

# %%
#example
#videoID = "543118554" #faker's video
#videoID = "554865944"

#twitch api OAuth
Clientid = "" #api client id 입력

#영상 정보 요청
url = "https://api.twitch.tv/kraken/videos/"+videoID
req = urllib.request.Request(url, headers = {"Client-ID": Clientid, "Accept" : "application/vnd.twitchtv.v5+jason"})
u = urllib.request.urlopen(req)
c = u.read().decode('utf-8')
js = json.loads(c)

# %%
js
# Out:
# {'title': '[플4 play] 캐서린 풀 보디 (스포일러 포함)',
#  'description': None,
#  'description_html': None,
#  'broadcast_id': 37078398592,
#  'broadcast_type': 'archive',
#  'status': 'recorded',
#  'tag_list': '',
#  'views': 1,
#  'url': 'https://www.twitch.tv/videos/562148164',
#  'language': 'ko',
#  'created_at': '2020-03-05T05:21:09Z',
#  'viewable': 'public',
#  'viewable_at': None,
#  'published_at': '2020-03-05T05:21:09Z',
#  'delete_at': '2020-03-19T05:21:09Z',
#  '_id': 'v562148164',
#  'recorded_at': '2020-03-05T05:21:09Z',
#  'game': '캐서린 풀 보디',
#  'length': 4228,
#  'preview': {'small': 'https://static-cdn.jtvnw.net/cf_vods/d2nvs31859zcd8/1ba652197e48f6c6733e_up36951_37078398592_1386172922/thumb/thumb0-80x45.jpg',
#     'url': 'https://static-cdn.jtvnw.net/cf_vods/d2nvs31859zcd8/1ba652197e48f6c6733e_up36951_37078398592_1386172922/thumb/thumb3-640x360.jpg'}],
#   'template': [{'type': 'generated',
#     'url': 'https://static-cdn.jtvnw.net/cf_vods/d2nvs31859zcd8/1ba652197e48f6c6733e_up36951_37078398592_1386172922/thumb/thumb0-{width}x{height}.jpg'},
#    {'type': 'generated',
#     'url': 'https://static-cdn.jtvnw.net/cf_vods/d2nvs31859zcd8/1ba652197e48f6c6733e_up36951_37078398592_1386172922/thumb/thumb1-{width}x{height}.jpg'},
#    {'type': 'generated',
#     'url': 'https://static-cdn.jtvnw.net/cf_vods/d2nvs31859zcd8/1ba652197e48f6c6733e_up36951_37078398592_1386172922/thumb/thumb2-{width}x{height}.jpg'},
#    {'type': 'generated',
#     'url': 'https://static-cdn.jtvnw.net/cf_vods/d2nvs31859zcd8/1ba652197e48f6c6733e_up36951_37078398592_1386172922/thumb/thumb3-{width}x{height}.jpg'}]},
#  'fps': {'160p30': 29.76364560469983,
#   '360p30': 29.76364560469983,
#   '480p30': 29.76364560469983,
#   '720p30': 29.76364560469983,
#   'chunked': 29.94825880483681},
#  'seek_previews_url': 'https://d2nvs31859zcd8.cloudfront.net/1ba652197e48f6c6733e_up36951_37078398592_1386172922/storyboards/562148164-info.json',
#  'resolutions': {'160p30': '284x160',
#   '360p30': '640x360',
#   '480p30': '852x480',
#   '720p30': '1280x720',
#   'chunked': '1280x720'},
#  'restriction': '',
#  'channel': {'mature': True,
#   'status': '[플4 play] 캐서린 풀 보디 (스포일러 포함)',
#   'broadcaster_language': 'ko',
#   'broadcaster_software': 'octodad',
#   'display_name': '필드미아',
#   'game': '캐서린 풀 보디',
#   'language': 'ko',
#   '_id': 486888333,
#   'name': 'up36951',
#   'created_at': '2020-01-20T05:08:27.52257Z',
#   'updated_at': '2020-03-05T06:51:52.820546Z',
#   'partner': False,
#   'logo': 'https://static-cdn.jtvnw.net/user-default-pictures-uv/de130ab0-def7-11e9-b668-784f43822e80-profile_image-300x300.png',
#   'video_banner': None,
#   'profile_banner': None,
#   'profile_banner_background_color': '',
#   'url': 'https://www.twitch.tv/up36951',
#   'views': 35,
#   'followers': 4,
#   'broadcaster_type': '',
#   'description': '',
#   'private_video': False,
#   'privacy_options_enabled': False},
#  'increment_view_count_url': 'https://countess.twitch.tv/ping.gif?u=%7B%22id%22%3A%22562148164%22%2C%22type%22%3A%22vod%22%7D'}

# %%
videoID = js['url'].split('/')[-1] #영상id 리스트로 수집시 변경 확인
offset = 0 #시작 위치

#반복구문의 영상정보 할당을 여기로 옮기는게 좋을지도...

cursor = ""
count = 0

while(1):
    print(str(count), end='\r')
    try:
        url2 = "https://api.twitch.tv/kraken/videos/"+str(videoID)+"/comments?cursor="+str(cursor)

        req2 = urllib.request.Request(url2, headers = {"Client-ID": Clientid, "Accept" : "application/vnd.twitchtv.v5+json"})
        u2 = urllib.request.urlopen(req2)
        c2 = u2.read().decode('utf-8')
        j2 = json.loads(c2)
        endCount = 0

        try:
            for number, com in enumerate(j2['comments']): #number=index, com=comment
                dateString = j2['comments'][number]['created_at']
                if "." in dateString:
                    dateString = re.sub(r".[0-9]+Z","Z", dateString)
                date = datetime.strptime(dateString, "%Y-%m-%dT%H:%M:%SZ")
                #if (int(offset) + int(duration)) < int(j2['comments'][number]['content_offset_seconds']): 
                    #endCount = 1
                    #print('duration')
                    #break #video의 경우 끝나지 않을 가능성 있음. 개선할 것
                #else:
                
                #완성 후 삭제
                
                #영상 정보
                title = str(js['title']) #영상 제목
                game = str(js['game']) #영상내 게임
                views = js['views'] #영상 시청수
                duration = js['length'] #방송 시간(초)
                url = str(js['url']) #영상 url
                
                #채팅 정보
                time = str(date + timedelta(hours=9)) #작성 시간
                timestamp = str(j2['comments'][12]['content_offset_seconds']) #영상 길이중 채팅입력 시간
                name = str(j2['comments'][number]['commenter']['name']) #작성자
                comment = str(j2['comments'][number]['message']['body']) #채팅
                try:
                    spent = j2['comments'][number]['message']['bits_spent'] #후원 액수
                    donation = 1 #후원 여부
                except:
                    spent = 0 #후원 채팅이 아닐 경우
                    donation = 0
                
                #dataframe append
                scrapTW=scrapTW.append({'title':title,'game_category':game,'view':views,'duration':duration,'vod_url':url,'donation':donation,'spent':spent,'chat_time':time, 'time_stamp':timestamp,'comment_user':name,'comments':comment},ignore_index = True)

        except Exception as e:
            print(e)

        #if endCount == 1:
            #break

        #j2['_next']가 없는 경우 예외처리로 pass
        try:
            if j2['_next']:
                cursor = j2['_next']
        except: 
            break

        count = count + 1 #offset을 사용할 경우
        
        #trial
        if count > 25:
            break

    except Exception as e:
        print(e)
# Out:
# 30

# %%
#scrapTW.loc[scrapTW["spent"] > 0,:]
#scrapTW.loc[scrapTW["spent"] > 0,:].iloc[0]
scrapTW.loc[scrapTW["spent"] > 0,:].iloc[0]['comments']
# Out:
# '선배님 여기가 시간과 공간의 방입니까..? 어서 이 맵에서 탈출해주십쇼.. Cheer100'

# %%
scrapTW
# Out:
#          title      game_category   view duration  \
# 0     T1 Faker  League of Legends  75397    14012
# 1     T1 Faker  League of Legends  75397    14012
# 2     T1 Faker  League of Legends  75397    14012
# 3     T1 Faker  League of Legends  75397    14012
# 4     T1 Faker  League of Legends  75397    14012
# 5     T1 Faker  League of Legends  75397    14012
# 6     T1 Faker  League of Legends  75397    14012
# 7     T1 Faker  League of Legends  75397    14012
# 8     T1 Faker  League of Legends  75397    14012
# 9     T1 Faker  League of Legends  75397    14012
# 10    T1 Faker  League of Legends  75397    14012
# 11    T1 Faker  League of Legends  75397    14012
# 12    T1 Faker  League of Legends  75397    14012
# 13    T1 Faker  League of Legends  75397    14012
# 14    T1 Faker  League of Legends  75397    14012
# 15    T1 Faker  League of Legends  75397    14012
# 16    T1 Faker  League of Legends  75397    14012
# 17    T1 Faker  League of Legends  75397    14012
# 18    T1 Faker  League of Legends  75397    14012
# 19    T1 Faker  League of Legends  75397    14012
# 20    T1 Faker  League of Legends  75397    14012
# 13                                                   페하
# 14                                                   hi
# 15                                                안녕하세유
# 16                                                 형!!!
# 17                                                   ㅎㅇ
# 18                                             ay faker
# 19                                                   페하
# 20                                                    ?
# 21                                          Hi ㅋㅋ Faker
# 22                                                   헬로
# 23                                                   페하
# 24                                                 페하!💜
# 25                                                   gg
# 26                                                  으흐흠
# 27                                                HELO!
# 28                                                  Pog
# 29                                                   페하
# ...                                                 ...
# 1753                                                 -4
# 1754                                                  씁
# 1755                                           ㅋㅋㅋㅋㅋㅋㅋㅋ
# 1756                                          KR cs LUL
# 1757                                                 -4
# 1758                                           good boy
# 1759                                                XDD
# 1760                                                버그네
# 1761                                                 CS
# 1762                                    sktfakerT1sweat
# 1763                                               !금지어
# 1764                                                 -4
# 1765                                                버근가
# 1766     potatoslicer124 -> https://imgur.com/a/VhFmc25
# 1767                                             버그네 ;;
# 1768                                                버그다
# 1769                                                  엄
# 1770                                                 -4
# 1771                                                LUL
# 1772                                         jasonrKEKW
# 1773                                                버근가
# 1774                                                버근가
# 1775                                                버그여
# 1776                                            - 3 LUL
# 1777                                        FeelsBadMan
# 1778                                                -20
# 1779                                               자강두천
# 1780                                            LUL LUL
# 1781  Please check the Chat Rule => https://imgur.co...
# 1782                                                 -6
#
# [1783 rows x 11 columns]

# %%
js['length'] #방송 시간(초)
# Out:
# 14012

# %%
a=j2['comments'][0]['created_at']
a=re.sub(r".[0-9]+Z","Z",a)
date = datetime.strptime(a, "%Y-%m-%dT%H:%M:%SZ")
date
# Out:
# datetime.datetime(2020, 1, 28, 14, 21, 36)

# %%
#영상 재생중 채팅 발생 시간대
str(timedelta(seconds=543.245))
# Out:
# '0:09:03.245000'

# %%
js['url'] #영상 url
# Out:
# 'https://www.twitch.tv/videos/543118554'

# %%
j2['comments'][10]
# Out:
# {'_id': 'c516daf2-087c-4e86-96be-b4b0427e7c69',
#  'created_at': '2020-01-28T14:38:53.152Z',
#  'updated_at': '2020-01-28T14:38:53.152Z',
#  'channel_id': '43691',
#  'content_type': 'video',
#  'content_id': '543118554',
#  'content_offset_seconds': 1047.452,
#  'commenter': {'display_name': '민_트루',
#   '_id': '195342322',
#   'name': 'mintrue0902',
#   'type': 'user',
#   'bio': '-ㅅ-',
#   'created_at': '2018-02-08T10:54:57.055318Z',
#   'updated_at': '2020-02-21T17:07:46.970561Z',
#   'logo': 'https://static-cdn.jtvnw.net/user-default-pictures-uv/215b7342-def9-11e9-9a66-784f43822e80-profile_image-300x300.png'},
#  'source': 'chat',
#  'state': 'published',
#  'message': {'body': '버근가',
#   'fragments': [{'text': '버근가'}],
#   'is_action': False,
#   'user_color': '#1E90FF',
#   'user_notice_params': {}}}

# %%
j2['comments'][12]['content_offset_seconds'] #영상 길이중 채팅입력 시간
# Out:
# 543.245

# %%
j2['comments'][12]['message']
# Out:
# {'body': '선배님 여기가 시간과 공간의 방입니까..? 어서 이 맵에서 탈출해주십쇼.. Cheer100',
#  'bits_spent': 100,
#  'fragments': [{'text': '선배님 여기가 시간과 공간의 방입니까..? 어서 이 맵에서 탈출해주십쇼.. Cheer100'}],
#  'is_action': False,
#  'user_badges': [{'_id': 'bits', 'version': '1000'}],
#  'user_notice_params': {}}

# %% [markdown]
# 비트 후원 액수

# %%
j2['comments'][12]['message']['bits_spent'] #bits_spent = bits 후원 액수, 후원이 아닌경우 포함되지 않음
# Out:
# 100

# %% [markdown]
# 채팅 내용

# %%
j2['comments'][12]['message']['body']
# Out:
# '선배님 여기가 시간과 공간의 방입니까..? 어서 이 맵에서 탈출해주십쇼.. Cheer100'

# %%
j2['comments'][12]['message']['fragments'][0]['text']
# Out:
# '선배님 여기가 시간과 공간의 방입니까..? 어서 이 맵에서 탈출해주십쇼.. Cheer100'

# %%
#content_offset_seconds = 채팅 입력 시간(초)
j2['comments'][12] #bits_spent = bits 후원 액수, 후원이 아닌경우 포함되지 않음
# Out:
# {'_id': '5f219e89-3c53-4b49-8741-3eceadaa08e1',
#  'created_at': '2020-01-28T14:30:28.945Z',
#  'updated_at': '2020-01-28T14:30:28.945Z',
#  'channel_id': '43691',
#  'content_type': 'video',
#  'content_id': '543118554',
#  'content_offset_seconds': 543.245,
#  'commenter': {'display_name': 'rlwkdb1001',
#   '_id': '181759419',
#   'name': 'rlwkdb1001',
#   'type': 'user',
#   'bio': '의진맨닮은꼴박보검',
#   'created_at': '2017-11-14T10:40:07.222907Z',
#   'updated_at': '2019-07-15T07:15:44.290329Z',
#   'logo': 'https://static-cdn.jtvnw.net/jtv_user_pictures/5d9441f5-e60a-4722-b1e5-db0be827ab30-profile_image-300x300.jpeg'},
#  'source': 'chat',
#  'state': 'published',
#  'message': {'body': '선배님 여기가 시간과 공간의 방입니까..? 어서 이 맵에서 탈출해주십쇼.. Cheer100',
#   'bits_spent': 100,
#   'fragments': [{'text': '선배님 여기가 시간과 공간의 방입니까..? 어서 이 맵에서 탈출해주십쇼.. Cheer100'}],
#   'is_action': False,
#   'user_badges': [{'_id': 'bits', 'version': '1000'}],
#   'user_notice_params': {}}}

# %%
#일반 채팅
j2['comments'][18]
# Out:
# {'_id': '24814fdf-6cfd-48d8-8a97-e1e412543424',
#  'created_at': '2020-01-28T14:38:53.869Z',
#  'updated_at': '2020-01-28T14:38:53.869Z',
#  'channel_id': '43691',
#  'content_type': 'video',
#  'content_id': '543118554',
#  'content_offset_seconds': 1048.169,
#  'commenter': {'display_name': 'rlacjftndudtn',
#   '_id': '198666393',
#   'name': 'rlacjftndudtn',
#   'type': 'user',
#   'bio': None,
#   'created_at': '2018-02-27T06:41:51.078425Z',
#   'updated_at': '2020-01-30T16:32:13.051136Z',
#   'logo': 'https://static-cdn.jtvnw.net/user-default-pictures-uv/998f01ae-def8-11e9-b95c-784f43822e80-profile_image-300x300.png'},
#  'source': 'chat',
#  'state': 'published',
#  'message': {'body': 'cs 버그다',
#   'fragments': [{'text': 'cs 버그다'}],
#   'is_action': False,
#   'user_notice_params': {}}}
